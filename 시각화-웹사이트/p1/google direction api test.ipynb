# %%
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyCuP0QbhWgKwx5mwDm1jV2pZXYU4FtGhQ4')

start_at = {"lat": 37.612085, "lng": 127.00825}
end_at = {"lat": 37.612085, "lng": 127.00825}


def get_direction(start_at, end_at):

    start_lat_lng = (start_at["lat"],start_at["lng"])
    end_lat_lng = (end_at["lat"],end_at["lng"])

    now = datetime.now()
    directions_result = gmaps.directions(start_lat_lng,
                                         end_lat_lng,
                                         mode="transit",
                                         departure_time=now)

    print(type(directions_result[0]))
    return directions_result
    
dir_test = get_direction(start_at, end_at)
# Out:
# <class 'dict'>

# %%
import pprint
pp = pprint.PrettyPrinter(indent = 4)

# %%
pp.pprint(dir_test)
# Out:
# [   {   'bounds': {   'northeast': {'lat': 37.6122829, 'lng': 127.0084122},
#                       'southwest': {'lat': 37.6115719, 'lng': 127.008004}},
#         'copyrights': 'Map data ©2020 SK telecom',
#         'legs': [   {   'arrival_time': {   'text': '10:42am',
#                                             'time_zone': 'Asia/Seoul',
#                                             'value': 1591148536},
#                         'departure_time': {   'text': '10:40am',
#                                               'time_zone': 'Asia/Seoul',
#                                               'value': 1591148404},
#                         'distance': {'text': '0.2 km', 'value': 177},
#                         'duration': {'text': '2 mins', 'value': 132},
#                         'end_address': 'South Korea, Seoul, Jeongneung '
#                                        '4(sa)-dong, 북한산보국문',
#                         'end_location': {'lat': 37.612085, 'lng': 127.00825},
#                         'start_address': 'South Korea, Seoul, Jeongneung '
#                                          '4(sa)-dong, 북한산보국문',
#                         'start_location': {'lat': 37.612085, 'lng': 127.00825},
#                         'steps': [   {   'distance': {   'text': '30 m',
#                                                          'value': 30},
#                                          'duration': {   'text': '1 min',
#                                                          'value': 31},
#                                          'end_location': {   'lat': 37.612274,
#                                                              'lng': 127.008004},
#                                          'html_instructions': 'Walk to '
#                                                               '북한산보국문역2번출구',
#                                          'polyline': {   'points': 'obqdFqhefWe@p@'},
#                                          'start_location': {   'lat': 37.612085,
#                                                                'lng': 127.00825},
#                                          'steps': [   {   'distance': {   'text': '30 '
#                                                                                   'm',
#                                                                           'value': 30},
#                                                           'duration': {   'text': '1 '
#                                                                                   'min',
#                                                                           'value': 31},
#                                                           'end_location': {   'lat': 37.612274,
#                                                                               'lng': 127.008004},
#                                                           'polyline': {   'points': 'obqdFqhefWe@p@'},
#                                                           'start_location': {   'lat': 37.612085,
#                                                                                 'lng': 127.00825},
#                                                           'travel_mode': 'WALKING'}],
#                                          'travel_mode': 'WALKING'},
#                                      {   'distance': {   'text': '89 m',
#                                                          'value': 89},
#                                          'duration': {   'text': '1 min',
#                                                          'value': 42},
#                                          'end_location': {   'lat': 37.61157499999999,
#                                                              'lng': 127.008421},
#                                          'html_instructions': 'Bus towards '
#                                                               'Jongno-gu '
#                                                               'Community '
#                                                               'Center, '
#                                                               'Sungin-dong',
#                                          'polyline': {   'points': 'ucqdF_gefWACRMZOzAo@@??A'},
#                                          'start_location': {   'lat': 37.612274,
#                                                                'lng': 127.008004},
#                                          'transit_details': {   'arrival_stop': {   'location': {   'lat': 37.61157499999999,
#                                                                                                     'lng': 127.008421},
#                                                                                     'name': 'KEB.하나은행.정릉중앙지점'},
#                                                                 'arrival_time': {   'text': '10:41am',
#                                                                                     'time_zone': 'Asia/Seoul',
#                                                                                     'value': 1591148477},
#                                                                 'departure_stop': {   'location': {   'lat': 37.612274,
#                                                                                                       'lng': 127.008004},
#                                                                                       'name': '북한산보국문역2번출구'},
#                                                                 'departure_time': {   'text': '10:40am',
#                                                                                       'time_zone': 'Asia/Seoul',
#                                                                                       'value': 1591148435},
#                                                                 'headsign': 'Jongno-gu '
#                                                                             'Community '
#                                                                             'Center, '
#                                                                             'Sungin-dong',
#                                                                 'headway': 480,
#                                                                 'line': {   'agencies': [   {   'name': '서울특별시버스운송사업조합',
#                                                                                                 'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#                                                                             'color': '#0abb0c',
#                                                                             'name': '서울 '
#                                                                                     '지선버스',
#                                                                             'short_name': '1014',
#                                                                             'text_color': '#ffffff',
#                                                                             'vehicle': {   'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#                                                                                            'name': 'Bus',
#                                                                                            'type': 'BUS'}},
#                                                                 'num_stops': 1},
#                                          'travel_mode': 'TRANSIT'},
#                                      {   'distance': {   'text': '58 m',
#                                                          'value': 58},
#                                          'duration': {   'text': '1 min',
#                                                          'value': 59},
#                                          'end_location': {   'lat': 37.612085,
#                                                              'lng': 127.00825},
#                                          'html_instructions': 'Walk to South '
#                                                               'Korea, Seoul, '
#                                                               'Jeongneung '
#                                                               '4(sa)-dong, '
#                                                               '북한산보국문',
#                                          'polyline': {   'points': 'i_qdFsiefWeB`@'},
#                                          'start_location': {   'lat': 37.61157499999999,
#                                                                'lng': 127.008421},
#                                          'steps': [   {   'distance': {   'text': '58 '
#                                                                                   'm',
#                                                                           'value': 58},
#                                                           'duration': {   'text': '1 '
#                                                                                   'min',
#                                                                           'value': 59},
#                                                           'end_location': {   'lat': 37.612085,
#                                                                               'lng': 127.00825},
#                                                           'polyline': {   'points': 'i_qdFsiefWeB`@'},
#                                                           'start_location': {   'lat': 37.61157499999999,
#                                                                                 'lng': 127.008421},
#                                                           'travel_mode': 'WALKING'}],
#                                          'travel_mode': 'WALKING'}],
#                         'traffic_speed_entry': [],
#                         'via_waypoint': []}],
#         'overview_polyline': {'points': 'obqdFqhefWe@p@ACn@]|Ao@eB^'},
#         'summary': '',
#         'warnings': [   'Walking directions are in beta. Use caution – This '
#                         'route may be missing sidewalks or pedestrian paths.'],
#         'waypoint_order': []}]
