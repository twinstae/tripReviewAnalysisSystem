# %%
import json
import urllib
import pandas as pd
import os
from os import path 
from time import time
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "TRAS.settings")
import django
from django.core.exceptions import ObjectDoesNotExist
django.setup()
from django.db import transaction
from django.conf import settings
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from django_pandas.io import read_frame
# %matplotlib inline
import pprint
from proto.models import Attraction, Review, Route
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyCuP0QbhWgKwx5mwDm1jV2pZXYU4FtGhQ4')
from django.db.models.query import DoesNotExist
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-8d649a2c51e0> in <module>
#      22 from datetime import datetime
#      23 gmaps = googlemaps.Client(key='AIzaSyCuP0QbhWgKwx5mwDm1jV2pZXYU4FtGhQ4')
# ---> 24 from django.db.models.query import DoesNotExist
#
# ImportError: cannot import name 'DoesNotExist' from 'django.db.models.query' (C:\Users\Jeong\Anaconda3\lib\site-packages\django\db\models\query.py)

# %% [markdown]
# 구글 API를 이용한 경로 값 크롤링
#
# 1. 경로쌍(튜플)을 불러온다.
#
# 2. 경로쌍에 있는 pk 값으로 어트랙션의 경도와 위도를 찾는다. 출발지인 어트랙션의 이름으로 위도와 경도를 찾아온다.
#
# 3. 구글 API로 경로를 구한다.
#
# 4. 구한 경로를 원하는 부분만 추출하여 JSON형식으로 저장한다.
#
# 5. update를 활용하여 경로를 저장한다.

# %%
start_ast = {"lat": 37.612085, "lng": 127.00825}
end_ast = {"lat": 37.612085, "lng": 127.00825}

p_test = get_direction(start_ast, end_ast)

# %%
pp = pprint.PrettyPrinter(indent = 4)
pp.pprint(p_test)
# Out:
# [   {   'bounds': {   'northeast': {'lat': 37.6122829, 'lng': 127.008421},
#                       'southwest': {   'lat': 37.61157499999999,
#                                        'lng': 127.008004}},
#         'copyrights': 'Map data ©2020 SK telecom',
#         'legs': [   {   'arrival_time': {   'text': '4:57pm',
#                                             'time_zone': 'Asia/Seoul',
#                                             'value': 1591948672},
#                         'departure_time': {   'text': '4:56pm',
#                                               'time_zone': 'Asia/Seoul',
#                                               'value': 1591948573},
#                         'distance': {'text': '0.1 km', 'value': 147},
#                         'duration': {'text': '2 mins', 'value': 99},
#                         'end_address': 'South Korea, Seoul, Jeongneung '
#                                        '4(sa)-dong, 북한산보국문',
#                         'end_location': {'lat': 37.612085, 'lng': 127.00825},
#                         'start_address': 'South Korea, Seoul, Jeongneung '
#                                          '4(sa)-dong, 북한산보국문',
#                         'start_location': {'lat': 37.612274, 'lng': 127.008004},
#                         'steps': [   {   'distance': {   'text': '89 m',
#                                                          'value': 89},
#                                          'duration': {   'text': '1 min',
#                                                          'value': 40},
#                                          'end_location': {   'lat': 37.61157499999999,
#                                                              'lng': 127.008421},
#                                          'html_instructions': 'Bus towards 월곡동',
#                                          'polyline': {   'points': 'ucqdF_gefWACRMZOzAo@@??A'},
#                                          'start_location': {   'lat': 37.612274,
#                                                                'lng': 127.008004},
#                                          'transit_details': {   'arrival_stop': {   'location': {   'lat': 37.61157499999999,
#                                                                                                     'lng': 127.008421},
#                                                                                     'name': 'KEB.하나은행.정릉중앙지점'},
#                                                                 'arrival_time': {   'text': '4:56pm',
#                                                                                     'time_zone': 'Asia/Seoul',
#                                                                                     'value': 1591948613},
#                                                                 'departure_stop': {   'location': {   'lat': 37.612274,
#                                                                                                       'lng': 127.008004},
#                                                                                       'name': '북한산보국문역2번출구'},
#                                                                 'departure_time': {   'text': '4:56pm',
#                                                                                       'time_zone': 'Asia/Seoul',
#                                                                                       'value': 1591948573},
#                                                                 'headsign': '월곡동',
#                                                                 'headway': 780,
#                                                                 'line': {   'agencies': [   {   'name': '서울특별시버스운송사업조합',
#                                                                                                 'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#                                                                             'color': '#0abb0c',
#                                                                             'name': '서울 '
#                                                                                     '지선버스',
#                                                                             'short_name': '1113',
#                                                                             'text_color': '#ffffff',
#                                                                             'vehicle': {   'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#                                                                                            'name': 'Bus',
#                                                                                            'type': 'BUS'}},
#                                                                 'num_stops': 1},
#                                          'travel_mode': 'TRANSIT'},
#                                      {   'distance': {   'text': '58 m',
#                                                          'value': 58},
#                                          'duration': {   'text': '1 min',
#                                                          'value': 59},
#                                          'end_location': {   'lat': 37.612085,
#                                                              'lng': 127.00825},
#                                          'html_instructions': 'Walk to South '
#                                                               'Korea, Seoul, '
#                                                               'Jeongneung '
#                                                               '4(sa)-dong, '
#                                                               '북한산보국문',
#                                          'polyline': {   'points': 'i_qdFsiefWeB`@'},
#                                          'start_location': {   'lat': 37.61157499999999,
#                                                                'lng': 127.008421},
#                                          'steps': [   {   'distance': {   'text': '58 '
#                                                                                   'm',
#                                                                           'value': 58},
#                                                           'duration': {   'text': '1 '
#                                                                                   'min',
#                                                                           'value': 59},
#                                                           'end_location': {   'lat': 37.612085,
#                                                                               'lng': 127.00825},
#                                                           'polyline': {   'points': 'i_qdFsiefWeB`@'},
#                                                           'start_location': {   'lat': 37.61157499999999,
#                                                                                 'lng': 127.008421},
#                                                           'travel_mode': 'WALKING'}],
#                                          'travel_mode': 'WALKING'}],
#                         'traffic_speed_entry': [],
#                         'via_waypoint': []}],
#         'overview_polyline': {'points': 'ucqdF_gefWACRMvB_A@AeB`@'},
#         'summary': '',
#         'warnings': [   'Walking directions are in beta. Use caution – This '
#                         'route may be missing sidewalks or pedestrian paths.'],
#         'waypoint_order': []}]

# %%
def get_direction(start_at, end_at):

    now = datetime.now()
    directions_result = gmaps.directions(start_at,
                                         end_at,
                                         mode="transit",
                                         departure_time=now)
    return directions_result # type을 넣어 출력하면 리스트 형태가 나옵니다 json 형태로 다시 바꾸어줄 필요가 있을까요?

# %%
list_tup = []

for route in Route.objects.all():
    
    try:
        start = route.start_pk
        end = Attraction.objects.get(pk = route.end_pk) # 이부분에서 end_pk를 찾을 수 없다는 애러가 등장합니다. route.end_pk OR Route.end_pk?
    except Attraction.DoesNotExist:
        print(route.start_pk)
        print("결측치가 존재합니다.")

    start_tup = (start.latitude, start.longitude)
    end_tup = (end.latitude, end.longitude)
    
    start_end = (start_tup, end_tup)
    list_tup.append(start_end)
print(list_tup)
# Out:
# Trickeye Museum Seoul
# 결측치가 존재합니다.
# Jogyesa Temple
# 결측치가 존재합니다.
# Dongdaemun Design Plaza (DDP)
# 결측치가 존재합니다.
# Love Museum
# 결측치가 존재합니다.
# Leeum Samsung Museum of Art
# 결측치가 존재합니다.
# Korean Postage Stamp Museum
# 결측치가 존재합니다.
# Gilsangsa Shrine
# 결측치가 존재합니다.
# The Story of King Sejong & The Story of Admiral Yi Sunshin
# 결측치가 존재합니다.
# Eungbongsan Mountain
# 결측치가 존재합니다.
# KBS On
# 결측치가 존재합니다.
# Dongdaemun Seonggwak Park
# 결측치가 존재합니다.
# Children’s Museum of National Museum of Korea
# 결측치가 존재합니다.
# Deoksugung
# 결측치가 존재합니다.
# Lotte World Aquarium
# 결측치가 존재합니다.
# National Folk Museum of Korea
# 결측치가 존재합니다.
# Shinsegae Dept. Store Main
# 결측치가 존재합니다.
# Seolleung & Jeongneung Royal Tomb
# 결측치가 존재합니다.
# [((37.5773616, 126.976684), (37.612085, 127.00825)), ((37.5773616, 126.976684), (37.5640907, 126.99794)), ((37.5773616, 126.976684), (37.5246635, 126.977727)), ((37.5773616, 126.976684), (37.5129907, 127.102732)), ((37.5773616, 126.976684), (37.566535, 126.977969)), ((37.5773616, 126.976684), (37.566535, 126.977969)), ((37.5773616, 126.976684), (37.566535, 126.977969)), ((37.5773616, 126.976684), (37.5509473, 126.989296)), ((37.5773616, 126.976684), (37.5511694, 126.988226)), ((37.5773616, 126.976684), (37.5635611, 126.983684)), ((37.5773616, 126.976684), (37.566535, 126.977969)), ((37.5773616, 126.976684), (37.5674467, 126.88545)), ((37.5773616, 126.976684), (37.5534897, 126.91773)), ((37.5773616, 126.976684), (37.5642551, 126.950307)), ((37.5773616, 126.976684), (37.51168500000001, 127.059339)), ((37.5773616, 126.976684), (37.5129907, 127.102732)), ((37.5773616, 126.976684), (37.5691357, 127.00907)), ((37.5773616, 126.976684), (37.5652675, 127.008417)), ((37.5773616, 126.976684), (37.5900117, 127.031858)), ((37.5773616, 126.976684), (37.5729503, 126.979357)), ((37.5773616, 126.976684), (37.5112348, 127.098027)), ((37.5773616, 126.976684), (37.568063, 127.008477)), ((37.5773616, 126.976684), (37.5216852, 126.98397)), ((37.5773616, 126.976684), (37.5041299, 127.003069)), ((37.5773616, 126.976684), (37.5238506, 126.98047)), ((37.5773616, 126.976684), (37.5686956, 127.011812)), ((37.5773616, 126.976684), (37.55097689999999, 126.9257)), ((37.5773616, 126.976684), (37.5642629, 126.974675)), ((37.5773616, 126.976684), (37.4996897, 126.978509)), ((37.5773616, 126.976684), (
 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 5}, 'travel_mode': 'TRANSIT'}, {'distance': {'text': '4.7 km', 'value': 4725}, 'duration': {'text': '9 mins', 'value': 550}, 'end_location': {'lat': 37.6120999, 'lng': 127.0083589}, 'html_instructions': 'Bus towards 정릉', 'polyline': {'points': 'itldFkhefWACg@qAQs@Yw@AAk@gBgCoG}EmL{@gCc@gBo@uI}@wCo@oAo@qAACg@q@uAaBGKiMiO{BiAgCo@oBGA?_CIcL_@mC[oBa@q@Ue@_@a@i@IKQWCEy@oBACiD}G?YJIDCjBuArBvA`A~@f@xBNhAJr@@B\\vD@l@IzA[pDc@xDg@zCO`A{@~D?@sCvNKrA@BBpAADCx@Fv@@xAGx@Kp@Md@iB~Bm@vAILc@HaA\\k@TA?iCt@_C~@yDfBgA^yBn@kA\\w@LiBL]Ly@`@}ClBSJ{Ap@]L{@d@A??C'}, 'start_location': {'lat': 37.589326, 'lng': 127.008218}, 'transit_details': {'arrival_stop': {'location': {'lat': 37.6120999, 'lng': 127.0083589}, 'name': '북한산보국문역1번출구'}, 'arrival_time': {'text': '11:24pm', 'time_zone': 'Asia/Seoul', 'value': 1591971889}, 'departure_stop': {'location': {'lat': 37.589326, 'lng': 127.008218}, 'name': '삼선교.한성대학교.조소앙활동터'}, 'departure_time': {'text': '11:15pm', 'time_zone': 'Asia/Seoul', 'value': 1591971339}, 'headsign': '정릉', 'headway': 420, 'line': {'agencies': [{'name': '서울특별시버스운송사업조합', 'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}], 'color': '#374ff2', 'name': '서울 간선버스', 'short_name': '143', 'text_color': '#ffffff', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 10}, 'travel_mode': 'TRANSIT'}], 'tra ...

# %%
def direction_update:
    update_json = json.dumps(update_list) # 저장은 JSON으로 해야하기 때문에 JSON으로 변환시켜줍니다. 그런데 리스트를 json으로 바꿀 수 있을까요? 

    if len(update_list) > 1: # 이상한 값이 들어가지 않게 해줍니다.
        Route.objects.bulk_update(update_json, ['direction']) # 전체 json 파일을 Route.direction에 update시킵니다

# %%
direction_test = "https://maps.googleapis.com/maps/api/directions/json?origin=37.5773616,126.9766844&destination=37.5774587,126.9733411&mode=transit&key=AIzaSyCuP0QbhWgKwx5mwDm1jV2pZXYU4FtGhQ4"

json_file = urllib.request.urlopen(direction_test)

json_result = json.load(json_file)

direction = json_result["routes"]

print(direction)
# Out:
# [{'bounds': {'northeast': {'lat': 37.5774587, 'lng': 126.9819911}, 'southwest': {'lat': 37.575708, 'lng': 126.9710619}}, 'copyrights': 'Map data ©2020 SK telecom', 'legs': [{'arrival_time': {'text': '12:14am', 'time_zone': 'Asia/Seoul', 'value': 1591888452}, 'departure_time': {'text': '11:57pm', 'time_zone': 'Asia/Seoul', 'value': 1591887468}, 'distance': {'text': '1.7 km', 'value': 1711}, 'duration': {'text': '16 mins', 'value': 984}, 'end_address': '21 Jahamun-ro 4-gil, Tongui-dong, Jongno-gu, Seoul, South Korea', 'end_location': {'lat': 37.5774587, 'lng': 126.9733411}, 'start_address': '161 Sajik-ro, Jongno 1(il).2(i).3(sam).4(sa), Jongno-gu, Seoul, South Korea', 'start_location': {'lat': 37.5773616, 'lng': 126.9766844}, 'steps': [{'distance': {'text': '0.5 km', 'value': 496}, 'duration': {'text': '8 mins', 'value': 497}, 'end_location': {'lat': 37.575866, 'lng': 126.981991}, 'html_instructions': 'Walk to 덕성여중고', 'polyline': {'points': 'oijdFgc_fWhHe`@'}, 'start_location': {'lat': 37.5773616, 'lng': 126.9766844}, 'steps': [{'distance': {'text': '0.5 km', 'value': 496}, 'duration': {'text': '8 mins', 'value': 497}, 'end_location': {'lat': 37.575866, 'lng': 126.981991}, 'polyline': {'points': 'oijdFgc_fWhHe`@'}, 'start_location': {'lat': 37.5773616, 'lng': 126.9766844}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '1.0 km', 'value': 972}, 'duration': {'text': '3 mins', 'value': 208}, 'end_location': {'lat': 37.576222, 'lng': 126.971062}, 'html_instructions': 'Bus towards Eunpyeong Public Garage', 'polyline': {'points': 'e`jdFmd`fWWxCWxFZrEHbAh@tG[~MI~CUjEWvCQbF'}, 'start_location': {'lat': 37.575866, 'lng': 126.981991}, 'transit_details': {'arrival_stop': {'location': {'lat': 37.576222, 'lng': 126.971062}, 'name': 'Sajik-dong Community Service Center'}, 'arrival_time': {'text': '12:09am', 'time_zone': 'Asia/Seoul', 'value': 1591888173}, 'departure_stop': {'location': {'lat': 37.575866, 'lng': 126.981991}, 'name': '덕성여중고'}, 'departure_time': {'text': '12:06am', 'time_zone': 'Asia/Seoul', 'value': 1591887965}, 'headsign': 'Eunpyeong Public Garage', 'headway': 720, 'line': {'agencies': [{'name': '서울특별시버스운송사업조합', 'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}], 'color': '#0abb0c', 'name': '서울 지선버스', 'short_name': '7025', 'text_color': '#ffffff', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 1}, 'travel_mode': 'TRANSIT'}, {'distance': {'text': '0.2 km', 'value': 243}, 'duration': {'text': '4 mins', 'value': 244}, 'end_location': {'lat': 37.5774587, 'lng': 126.9733411}, 'html_instructions': 'Walk to 21 Jahamun-ro 4-gil, Tongui-dong, Jongno-gu, Seoul, South Korea', 'polyline': {'points': 'kbjdFc`~eWwFgM'}, 'start_location': {'lat': 37.576222, 'lng': 126.971062}, 'steps': [{'distance': {'text': '0.2 km', 'value': 243}, 'duration': {'text': '4 mins', 'value': 244}, 'end_location': {'lat': 37.5774587, 'lng': 126.9733411}, 'polyline': {'points': 'kbjdFc`~eWwFgM'}, 'start_location': {'lat': 37.576222, 'lng': 126.971062}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}], 'traffic_speed_entry': [], 'via_waypoint': []}], 'overview_polyline': {'points': 'oijdFgc_fWhHe`@WxCWxFd@vGh@tG[~MI~CUjEWvCQbFwFgM'}, 'summary': '', 'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'], 'waypoint_order': []}]
